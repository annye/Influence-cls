# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# from tabulate import tabulate
# from statistics import StatisticalTests
# #from statistics import shapiro_test
# from tabulate import tabulate
# import scipy.stats as stats
# from scikit_posthocs import posthoc_dunn
# import scipy.stats as stats
# import seaborn as sns
# from scipy.stats import friedmanchisquare, norm, probplot, shapiro, wilcoxon, binom_test
# import scikit_posthocs
# from math import pi
# from scipy.stats import kruskal

# import warnings
# warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\phaseII\static\\survey-first-2020.csv")

# %% [markdown]
# ### Gender Distribution

# %%
set(df['gender'])
# Out:
# {'Female', 'Male', 'Non-binary'}

# %%
df.head(2)
# Out:
#    age  gender  Extraversion  Agreeableness  Conscientiousness
# 0   48  Female           4.5            4.5                4.0  \
# 1   29    Male           6.0            5.0                5.0
#
#    Emotional_stability  Openness  Approval  Love  Achievement  ...
# 0                  3.0       5.0         0     3           -2  ...  \
# 1                  4.5       4.5         1     2            0  ...
#
#    appeal_finances  awareness_words  semantic_repetition_priming
# 0                1                2                            2  \
# 1                2                3                            3
#
#    appeal_to_logic  flattery  device_rhetorical_question  device_epistrophe
# 0                4         4                           3                  3  \
# 1                5         5                           4                  4
#
#    device_anaphora  device_antanagoge  Illusion_of_superiority
# 0                8                  6                        6
# ...

# %%
gender_counts = df['gender'].value_counts()

# Plotting the bar plot
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
female = df[df['gender'] == 'Female'] 
male = df[df['gender'] == 'Male'] 
female = df[df['gender'] == 'Female']


# Adding labels with the total count in each bar
for i, count in enumerate(gender_counts.values):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.show()

# %%
gender_counts = df['gender'].value_counts()

# Plotting the bar plot
plt.bar(gender_counts.index, gender_counts.values, color=['pink', 'blue', 'purple'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')

# Adding labels with the total count in each bar
for i, count in enumerate(gender_counts.values):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.show()

# %%
female = df[df['gender'] == 'Female']
male = df[df['gender'] == 'Male']
non_binary = df[df['gender'] == 'Non-binary']

# Define the mapping dictionary
mapping = {'Female': 2, 'Male': 1, 'Non-binary': 0}

# Map the 'gender' column to numeric values
df['gender_numeric'] = df['gender'].map(mapping)



print('Female total:',female.shape[0])
print('Male total:',male.shape[0])
# Out:
# Female total: 511
# Male total: 500

# %% [markdown]
# ### Visualization Personality Traits by Gender

# %%
female['Extraversion'].mean()
# Out:
# 4.3600782778864975

# %%
male['Extraversion'].mean()
# Out:
# 4.288

# %%
# Define column names
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional_stability']
columns = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional_stability']

# Compute means iteratively
values = []
for col in columns:
    mean = male[col].mean()
    values.append(mean)

# Create a figure with a polar projection
fig = plt.figure(figsize=(18, 14))
ax = fig.add_subplot(111, polar=True)

# Define angles and plot values
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, alpha=0.3)

# Add x-axis labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontweight='bold')

# Add labels with mean values
for angle, value in zip(angles[:-1], values[:-1]):
    ax.text(angle, value, f'{value:.2f}', ha='center', va='center')

title = ax.set_title('Average Personality Traits (Male)', fontsize=14, fontweight='bold', pad=20)
title.set_position([0.5, 1.1])

# Show the plot
plt.show()

# %%
# Define column names
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional_stability']
columns = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional_stability']

# Compute means iteratively
values = []
for col in columns:
    mean = female[col].mean()
    values.append(mean)

# Create a figure with a polar projection
fig = plt.figure(figsize=(18, 10))
ax = fig.add_subplot(111, polar=True)

# Define angles and plot values
angles = [n / float(len(categories)) * 2 * np.pi for n in range(len(categories))]
angles += angles[:1]
values += values[:1]

# Plot the data
ax.plot(angles, values, linewidth=1, linestyle='solid', color='pink')
ax.fill(angles, values, alpha=0.3, color='pink')

# Add x-axis labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontweight='bold')

# Add labels with mean values
for angle, value in zip(angles[:-1], values[:-1]):
    ax.text(angle, value, f'{value:.2f}', ha='center', va='center')

# Set the title
title = ax.set_title('Average Personality Traits (Female)', fontsize=14, fontweight='bold', pad=20)
title.set_position([0.5, 1.1])

# Show the plot
plt.show()

# %%
# Define column names
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional_stability']
columns = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional_stability']

# Compute means iteratively
values = []
for col in columns:
    mean = non_binary[col].mean()
    values.append(mean)

# Create a figure with a polar projection
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, polar=True)

# Define angles and plot values
angles = [n / float(len(categories)) * 2 * np.pi for n in range(len(categories))]
angles += angles[:1]
values += values[:1]

# Plot the data
ax.plot(angles, values, linewidth=1, linestyle='solid', color='purple')
ax.fill(angles, values, alpha=0.3, color='purple')

# Add x-axis labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontweight='bold')

# Add labels with mean values
for angle, value in zip(angles[:-1], values[:-1]):
    ax.text(angle, value, f'{value:.2f}', ha='center', va='center')

# Set the title
title = ax.set_title('Average Personality Traits (Non-Binary)', fontsize=14, fontweight='bold', pad=20)
title.set_position([0.5, 1.1])

# Show the plot
plt.show()

# %%
# Convert the columns to a dataframe
df_columns = female[['Love', 'Achievement', 'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy']]
categories = ['Love', 'Achievement', 'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy']

# Calculate the means for each trait
means = df_columns.mean()



# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8, 6))

# Set seaborn style and color palette
sns.set(style='whitegrid', palette='pastel')

# Plot the bar chart
sns.barplot(x=categories, y=means, ax=ax)

# Set title and axis labels
ax.set_title('Dysfunctional Attitude Scale (DAS) for Females Individuals', fontsize=16, fontweight='bold')
ax.set_xlabel('Items ', fontsize=12, fontweight='bold')
ax.set_ylabel('Values', fontsize=12, fontweight='bold')

# Set axis tick parameters
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

# Show the chart
plt.show()

# %%
# Convert the columns to a dataframe
df_columns = male[['Love', 'Achievement', 'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy']]
categories = ['Love', 'Achievement', 'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy']

# Calculate the means for each trait
means = df_columns.mean()



# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8, 6))

# Set seaborn style and color palette
sns.set(style='whitegrid', palette='pastel')

# Plot the bar chart
sns.barplot(x=categories, y=means, ax=ax)

# Set title and axis labels
ax.set_title('Dysfunctional Attitude Scale (DAS) for Male Individuals', fontsize=16, fontweight='bold')
ax.set_xlabel('Items ', fontsize=12, fontweight='bold')
ax.set_ylabel('Values', fontsize=12, fontweight='bold')

# Set axis tick parameters
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

# Show the chart
plt.show()

# %%
# Convert the columns to a dataframe
df_columns = non_binary[['Love', 'Achievement', 'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy']]
categories = ['Love', 'Achievement', 'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy']

# Calculate the means for each trait
means = df_columns.mean()



# Create a figure and axis object
fig, ax = plt.subplots(figsize=(8, 6))

# Set seaborn style and color palette
sns.set(style='whitegrid', palette='magma')

# Plot the bar chart
sns.barplot(x=categories, y=means, ax=ax)

# Set title and axis labels
ax.set_title('Dysfunctional Attitude Scale (DAS) for Non-Binary Individuals', fontsize=16, fontweight='bold')
ax.set_xlabel('Items ', fontsize=12, fontweight='bold')
ax.set_ylabel('Values', fontsize=12, fontweight='bold')

# Set axis tick parameters
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

# Show the chart
plt.show()

# %%
def shapiro_test(data):
    """
    Perform Shapiro-Wilk test of normality for each column in a pandas DataFrame.

    Parameters:
    data (pandas.DataFrame): Input DataFrame.

    Returns:
    pandas.DataFrame: DataFrame containing the results of the normality tests.
    """
    results = []
    for column in data.columns:
        stat, p = stats.shapiro(data[column])
        if p > 0.05:
            result = [column, stat, p, "Pass"]
        else:
            result = [column, stat, p, "Fail"]
        results.append(result)

    headers = ["Variable", "W-Value", "P-Value", "Normality"]
    return pd.DataFrame(results, columns=headers)

# %%
df = df[['age', 'gender_numeric', 'Extraversion', 'Agreeableness', 'Conscientiousness',
       'Emotional_stability', 'Openness', 'Approval', 'Love', 'Achievement',
       'Perfectionism', 'Entitlement', 'Omnipotence', 'Autonomy', 'authority',
       'social_proof', 'appeal_finances', 'awareness_words',
       'semantic_repetition_priming', 'appeal_to_logic', 'flattery',
       'device_rhetorical_question', 'device_epistrophe', 'device_anaphora',
       'device_antanagoge', 'Illusion_of_superiority' ]].astype(float)

# %%
from tabulate import tabulate
results = shapiro_test(df)
print(tabulate(results, headers='keys', tablefmt='fancy_grid'))
# Out:
# ╒════╤═════════════════════════════╤═══════════╤═════════════╤═════════════╕
# │    │ Variable                    │   W-Value │     P-Value │ Normality   │
# ╞════╪═════════════════════════════╪═══════════╪═════════════╪═════════════╡
# │  0 │ age                         │  0.864303 │ 8.04954e-29 │ Fail        │
# ├────┼─────────────────────────────┼───────────┼─────────────┼─────────────┤
# │  1 │ gender_numeric              │  0.672963 │ 2.02783e-40 │ Fail        │
# ├────┼─────────────────────────────┼───────────┼─────────────┼─────────────┤
# │  2 │ Extraversion                │  0.944266 │ 3.58832e-19 │ Fail        │
# ├────┼─────────────────────────────┼───────────┼─────────────┼─────────────┤
# │  3 │ Agreeableness               │  0.96735  │ 2.23255e-14 │ Fail        │
# ├────┼─────────────────────────────┼───────────┼─────────────┼─────────────┤
# │  4 │ Conscientiousness           │  0.948852 │ 2.37357e-18 │ Fail        │
# ...

# %%
techniques = df[[ 'authority', 'social_proof', 'appeal_finances', 'awareness_words',
'semantic_repetition_priming', 'appeal_to_logic', 'flattery',
'device_rhetorical_question', 'device_epistrophe', 'device_anaphora',
'device_antanagoge', 'Illusion_of_superiority']]

# %%
## Distribution of Influence Scores of the Average Persuasion Goal

# Set the style for the plot
sns.set(style='whitegrid')

# Create a boxplot for each technique
sns.boxplot(data=techniques, orient='h', palette='pastel')

# Add labels and title
plt.xlabel('Influence Scores Persuasive task: Promotion of Hight Level Education')
plt.title('Distribution of Influence Scores')
plt.show()

# %%
from tabulate import tabulate
from itertools import combinations
from pdb import set_trace
# Perform the Friedman test
stat, p = friedmanchisquare(*[techniques[col] for col in techniques.columns])

alpha = 0.05
k = 10  # Number of tests (persuasion techniques)
bonf_alpha = alpha / k

print(f"Friedman Test: Test Statistic = {stat:.3f}, p-value = {p:.3f}")




# Check if the difference is significant after Bonferroni correction
if p <= bonf_alpha:
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")

# Create a table to display the results
headers = ['Test', 'Value']
table_data = [['Friedman test (Chi-squared)', '{:.4f}'.format(stat)],
              ['Friedman test (Degrees of freedom)', '{}'.format(len(techniques.columns)-1)],
              ['Friedman test (P value)', '{:.4f}'.format(p)],
              ['Bonferroni-adjusted significance level', '{:.4f}'.format(bonf_alpha)],
              ['Significance after Bonferroni correction', 'Yes' if p <= bonf_alpha else 'No']]

table = tabulate(table_data, headers=headers, tablefmt="fancy_grid")
print(table)
# Out:
# Friedman Test: Test Statistic = 1324.188, p-value = 0.000
# The difference is statistically significant.
# ╒══════════════════════════════════════════╤═══════════╕
# │ Test                                     │ Value     │
# ╞══════════════════════════════════════════╪═══════════╡
# │ Friedman test (Chi-squared)              │ 1324.1883 │
# ├──────────────────────────────────────────┼───────────┤
# │ Friedman test (Degrees of freedom)       │ 11        │
# ├──────────────────────────────────────────┼───────────┤
# │ Friedman test (P value)                  │ 0.0000    │
# ├──────────────────────────────────────────┼───────────┤
# │ Bonferroni-adjusted significance level   │ 0.0050    │
# ├──────────────────────────────────────────┼───────────┤
# │ Significance after Bonferroni correction │ Yes       │
# ╘══════════════════════════════════════════╧═══════════╛

# %%
# Bonferroni correction
alpha = 0.05
k = len(list(combinations(techniques.columns, 2)))  # Use the number of pairwise comparisons
bonf_alpha = alpha / k  # original_significance_level / number_of_tests.

wilcoxon_results = []
for col1, col2 in combinations(techniques.columns, 2):
    statistic, p_value = wilcoxon(techniques[col1], techniques[col2])  # Calculates the test statistic (`statistic`) and the corresponding p-value (`p_value`).

    adjusted_p_value = min(p_value * k, 1.0)  # Bonferroni-adjusted p-value (bounded between 0 and 1)
    reject_null_pair = adjusted_p_value <= alpha

    # Determine the direction of the difference
    if reject_null_pair:
        if techniques[col1].mean() > techniques[col2].mean():
            direction = f"{col1} > {col2}"
        else:
            direction = f"{col2} > {col1}"
    else:
        direction = "-"

    wilcoxon_results.append((col1, col2, statistic, p_value, adjusted_p_value, reject_null_pair, direction))

# Create a table to display the results
headers = ['Test', 'TS', 'P-value', 'Adj. P-value', 'Significance', 'Direction']
table_data = []
for result in wilcoxon_results:
    pair = f"{result[0]} vs {result[1]}"
    stat = '{:.5f}'.format(result[2])
    p_value = '{:.5f}'.format(result[3])
    adjusted_p_value = '{:.5f}'.format(result[4])
    significant = 'Yes' if result[5] else 'No'
    direction = result[6]
    table_data.append([pair, stat, p_value, adjusted_p_value, significant, direction])

table = tabulate(table_data, headers=headers, tablefmt="fancy_grid")
print('')
print(f"Bonferroni-adjusted Significance Level: {bonf_alpha}")
print('')
print(table)
# Out:
# Bonferroni-adjusted Significance Level: 0.0007575757575757576
#
# ╒═══════════════════════════════════════════════════════════╤══════════╤═══════════╤════════════════╤════════════════╤══════════════════════════════════════════════════════════╕
# │ Test                                                      │       TS │   P-value │   Adj. P-value │ Significance   │ Direction                                                │
# ╞═══════════════════════════════════════════════════════════╪══════════╪═══════════╪════════════════╪════════════════╪══════════════════════════════════════════════════════════╡
# │ authority vs social_proof                                 │  96449   │   0       │        0       │ Yes            │ social_proof > authority                                 │
# ├───────────────────────────────────────────────────────────┼──────────┼───────────┼────────────────┼────────────────┼──────────────────────────────────────────────────────────┤
# ...

# %% [markdown]
# # Kuskal

# %%
def generate_boxplot(data, labels):
    
    # Creating a figure and axes
    fig, ax = plt.subplots()

    # Boxplot properties
    boxprops = dict(facecolor='white', color='black', linewidth=1.5)
    medianprops = dict(color='red', linewidth=2.5)
    whiskerprops = dict(color='black', linewidth=1.5)
    capprops = dict(color='black', linewidth=1.5)

    # Creating the boxplot
    boxplot = ax.boxplot(data, patch_artist=True, labels=labels,
                         boxprops=boxprops, medianprops=medianprops, whiskerprops=whiskerprops, capprops=capprops)

    # Set colors for each group
    colors = [ 'pink', 'blue']
    for patch, color in zip(boxplot['boxes'], colors):
        patch.set_facecolor(color)

    # Calculate standard deviations
    std_devs = [np.std(group) for group in data]

    # Adding title and labels
    title = 'Comparison of  Social Proof by Gender (Std:'
    for i in range(len(labels)):
        title += ' {}: {:.2f},'.format(labels[i], std_devs[i])
    title = title[:-1] + ')'
    ax.set_title(title)
    ax.set_xlabel('Gender')
    ax.set_ylabel(' Authority')

    # Setting the y-axis limits
    ax.set_ylim([0, max([max(group) for group in data]) + 1])

    # Adding a grid
    ax.grid(True, axis='y')

    # Show the plot
    plt.show()
    
labels = ['Female', 'Male']

# %%
def perform_Kruskal_Wallis(groups, group_names=None):
    #  Kruskal-Wallis test
    
    # Calculate degrees of freedom
    k = len(groups)  # Number of groups
    n = len(groups[0])  # Total sample size 
    df = k - 1
    
    # Perform the Kruskal-Wallis test
    statistic, p_value = stats.kruskal(*groups)
    p_value = max(0.0, min(p_value * k, 1.0))  # Bound the p-value between 0 and 1

    # Perform Dunn's test with Bonferroni adjustment
    dunn_results = scikit_posthocs.posthoc_dunn(groups, p_adjust='bonferroni')

  

    # Calculate chi-square value
    chi2 = (n - 1) * p_value

    
    # Determine if the null hypothesis is rejected
    alpha = 0.05
    reject_null = p_value < alpha
    

    # Bonferroni-adjusted significance level
    bonf_alpha = alpha / len(groups)

    # Calculate adjusted p-value
    adjusted_p_value = max(0.0, min(p_value * k, 1.0))  # Bonferroni-adjusted p-value (bounded between 0 and 1)

    # Determine significance after Bonferroni correction
    significance_after_correction = 'Yes' if adjusted_p_value <= bonf_alpha else 'No'

    # Prepare the table
    table = [
        ['Test', 'Value'],
        ['Chi-square', chi2],
        ['Degrees of Freedom', df],
        ['p-value', p_value],
        ['Bonferroni-adjusted significance level', '{:.4f}'.format(bonf_alpha)],
        ['Adjusted p-value', '{:.4f}'.format(adjusted_p_value)],
        ['Significance after Bonferroni correction', significance_after_correction]
    ]

    # Print the table using tabulate with fancy_grid
    print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))

    # Print the p-value
    print("Kruskal-Wallis p-value:", p_value)

    # Print the significance (reject or not reject)
    significance = 'Significant' if reject_null else 'Not Significant'
    print("Result:", significance)
    print('-----------------------------')
    print()

    # Print the pairwise comparison results
    print("Dunn's Pairwise Comparison:")
    labels = group_names or [str(i) for i in range(len(groups))]  # Use indices as labels if not provided
    table = [['Pairwise Comparison', 'p-value']]

    for i in range(len(dunn_results)):
        for j in range(i+1, len(dunn_results)):
            comp = f"{labels[i]} vs {labels[j]}"
            p_value = max(0.0, min(dunn_results.iloc[i, j], 1.0))  # Bound the p-value between 0 and 1
            table.append([comp, p_value])

    # Print the table using tabulate with fancy_grid
    print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
